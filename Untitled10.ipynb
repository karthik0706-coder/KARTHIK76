# %%
AIzaSyCrlJoukE8IcsECXeL4hiVYDxs8rDVNPn4
# Install necessary libraries for Colab
# !pip install -q langchain langchain-community google-generativeai

import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.schema import SystemMessage, HumanMessage

# Set up Gemini API key
os.environ["GOOGLE_API_KEY"] = "AIzaSyCrlJoukE8IcsECXeL4hiVYDxs8rDVNPn4"  # Replace with your actual Gemini 2.5 API key

# Initialize Gemini 2.5 Pro model
chatbot = ChatGoogleGenerativeAI(
    model="gemini-2.5-pro-exp-03-25",  # Gemini 2.5 Pro Experimental (or use "gemini-pro" for stable)
    temperature=0.7,
    max_output_tokens=1024
)

# Chat function
def chat_with_bot(user_input):
    messages = [
        SystemMessage(content="You are a helpful chatbot."),
        HumanMessage(content=user_input)
    ]
    response = chatbot(messages)
    return response.content

# Example usage
print("Chat with Gemini 2.5 Pro (type 'exit' to quit):")
while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit"]:
        break
    response = chat_with_bot(user_input)
    print("Bot:", response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7dfc1f661423> in <cell line: 0>()
# ----> 1 AIzaSyCrlJoukE8IcsECXeL4hiVYDxs8rDVNPn4
#       2 # Install necessary libraries for Colab
#       3 get_ipython().system('pip install -q langchain langchain-community google-generativeai')
#       4
#       5 import os
#
# NameError: name 'AIzaSyCrlJoukE8IcsECXeL4hiVYDxs8rDVNPn4' is not defined
